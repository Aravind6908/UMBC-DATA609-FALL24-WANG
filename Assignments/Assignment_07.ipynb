# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravind6908/UMBC-DATA609-FALL24-WANG/blob/main/Assignments/Assignment_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10/16/2024

# %%
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

print(df.shape)
df.sample(3)
# Out:
# (4123, 9)
#       Year        Country  GDP per capita (current US$)  \
# 3058  2022        Romania                  15786.801742
# 3924  2014  United States                  55123.849787
# 3669  2006    Timor-Leste                    456.272698
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3058                                      NaN         19047009.0          ROU
# 3924                                78.841463        318386329.0          USA
# 3669                                63.073000           994564.0          TLS
#
#                      Region         Income Group    Lending Type
# 3058  Europe & Central Asia          High income            IBRD
# 3924          North America          High income  Not classified
# 3669    East Asia & Pacific  Lower middle income           Blend

# %%
column_names_dict = {
    "GDP per capita (current US$)" : "GDP per Capita",
    "Life expectancy at birth, total (years)" : "Life Expectancy",
    "Population, total" : "Population"
}

df = df.rename(columns=column_names_dict)
df.sample(3)
# Out:
#       Year   Country  GDP per Capita  Life Expectancy  Population  \
# 976   2011    Cyprus    32395.753906           79.999   1145086.0
# 2280  2004  Malaysia     4924.338111           73.898  25333247.0
# 825   2012   Comoros     1483.951559           61.834    684553.0
#
#      Country Code                 Region         Income Group    Lending Type
# 976           CYP  Europe & Central Asia          High income  Not classified
# 2280          MYS    East Asia & Pacific  Upper middle income            IBRD
# 825           COM    Sub-Saharan Africa   Lower middle income             IDA

# %%
df.sample(3).T
# Out:
#                                   1432                        4036  \
# Year                              2011                        2012
# Country                      Gibraltar       Virgin Islands (U.S.)
# GDP per Capita                     NaN                37795.319259
# Life Expectancy                 81.871                   78.517073
# Population                     31701.0                    108188.0
# Country Code                       GIB                         VIR
# Region           Europe & Central Asia  Latin America & Caribbean
# Income Group               High income                 High income
# Lending Type            Not classified              Not classified
#
#                                 3252
# Year                            2007
# Country                    Singapore
# GDP per Capita           39432.88602
# Life Expectancy            80.441463
# Population                 4588599.0
# Country Code                     SGP
# Region           East Asia & Pacific
# Income Group             High income
# Lending Type          Not classified

# %% [markdown]
# ## Section One
#
# Summary Statistics with describe() function

# %%
df[["Population","Life Expectancy"]].describe()
# Out:
#          Population  Life Expectancy
# count  4.123000e+03      3777.000000
# mean   3.319575e+07        71.060853
# std    1.316430e+08         8.499806
# min    9.791000e+03        42.125000
# 25%    7.436200e+05        65.351000
# 50%    5.872624e+06        72.765000
# 75%    2.148494e+07        77.529000
# max    1.417173e+09        85.497561

# %%
df.describe()
# Out:
#              Year  GDP per Capita  Life Expectancy    Population
# count  4123.00000     3962.000000      3777.000000  4.123000e+03
# mean   2013.00000    17007.692848        71.060853  3.319575e+07
# std       5.47789    25733.109164         8.499806  1.316430e+08
# min    2004.00000      128.538423        42.125000  9.791000e+03
# 25%    2008.00000     1862.892400        65.351000  7.436200e+05
# 50%    2013.00000     6048.304202        72.765000  5.872624e+06
# 75%    2018.00000    22137.309568        77.529000  2.148494e+07
# max    2022.00000   240862.182448        85.497561  1.417173e+09

# %%
df.describe(include="object")
# Out:
#             Country Country Code                 Region Income Group  \
# count          4123         4123                   4123         4123
# unique          217          217                      7            5
# top     Afghanistan          AFG  Europe & Central Asia  High income
# freq             19           19                   1102         1558
#
#           Lending Type
# count             4123
# unique               4
# top     Not classified
# freq              1387

# %%
df.describe(include="object").T
# Out:
#              count unique                    top  freq
# Country       4123    217            Afghanistan    19
# Country Code  4123    217                    AFG    19
# Region        4123      7  Europe & Central Asia  1102
# Income Group  4123      5            High income  1558
# Lending Type  4123      4         Not classified  1387

# %% [markdown]
# ## Section Two
#
# Compute quartiles and transform a numerical column into a categorical column based on the quartiles.

# %%
def assign_quartile(gdp):
    if gdp <= 1862.89:
        quartile = "1st Quartile (<=25%)"
    elif gdp > 1862.89 and gdp <= 6048.30:
        quartile = "2nd Quartile (25-50%)"
    elif gdp > 6048.30 and gdp <= 22137.31:
        quartile = "3rd Quartile (50-75%)"
    else:
        quartile = "4th Quartile (>75%)"
    return quartile


hungary = assign_quartile(14294.25)
hungary
# Out:
# '3rd Quartile (50-75%)'

# %%
df_usa = df[df["Country Code"] == "USA"]
df_usa
# Out:
#       Year        Country  GDP per Capita  Life Expectancy   Population  \
# 3914  2004  United States    41724.631629        77.487805  292805298.0
# 3915  2005  United States    44123.407068        77.487805  295516599.0
# 3916  2006  United States    46302.000880        77.687805  298379912.0
# 3917  2007  United States    48050.223777        77.987805  301231207.0
# 3918  2008  United States    48570.045980        78.039024  304093966.0
# 3919  2009  United States    47194.943355        78.390244  306771529.0
# 3920  2010  United States    48650.643128        78.541463  309327143.0
# 3921  2011  United States    50065.966504        78.641463  311583481.0
# 3922  2012  United States    51784.418574        78.741463  313877662.0
# 3923  2013  United States    53291.127689        78.741463  316059947.0
# 3924  2014  United States    55123.849787        78.841463  318386329.0
# 3925  2015  United States    56762.729452        78.690244  320738994.0
# 3926  2016  United States    57866.744934        78.539024  323071755.0
# 3927  2017  United States    59907.754261        78.539024  325122128.0
# 3928  2018  United States    62823.309438        78.639024  326838199.0
# 3929  2019  United States    65120.394663        78.787805  328329953.0
# 3930  2020  United States    63528.634303        76.980488  331511512.0
# 3931  2021  United States    70219.472454        76.329268  332031554.0
# 3932  2022  United States    76329.582265              NaN  333287557.0
#
#      Country Code         Region Income Group    Lending Type
# 3914          USA  North America  High income  Not classified
# 3915          USA  North America  High income  Not classified
# 3916          USA  North America  High income  Not classified
# 3917          USA  North America  High income  Not classified
# 3918          USA  North America  High income  Not classified
# 3919          USA  North America  High income  Not classified
# 3920          USA  North America  High income  Not classified
# 3921          USA  North America  High income  Not classified
# 3922          USA  North America  High income  Not classified
# 3923          USA  North America  High income  Not classified
# 3924          USA  North America  High income  Not classified
# 3925          USA  North America  High income  Not classified
# 3926          USA  North America  High income  Not classified
# 3927          USA  North America  High income  Not classified
# 3928          USA  North America  High income  Not classified
# 3929          USA  North America  High income  Not classified
# 3930          USA  North America  High income  Not classified
# 3931          USA  North America  High income  Not classified
# 3932          USA  North America  High income  Not classified

# %%
assign_quartile(76329.58)
# Out:
# '4th Quartile (>75%)'

# %%
df_2020 = df[df["Year"] == 2020]
print(df_2020.shape[0])
print(f"There are {df_2020.shape[0]} countries in the 2020 dataset")
df_2020.sample(3)
# Out:
# 217
# There are 217 countries in the 2020 dataset
#       Year                   Country  GDP per Capita  Life Expectancy  \
# 35    2020                   Albania     5343.037704        76.989000
# 2201  2020                 Lithuania    20381.855783        74.978049
# 3493  2020  St. Martin (French part)             NaN        80.149000
#
#       Population Country Code                      Region  \
# 35     2837849.0          ALB       Europe & Central Asia
# 2201   2794885.0          LTU       Europe & Central Asia
# 3493     32553.0          MAF  Latin America & Caribbean
#
#              Income Group    Lending Type
# 35    Upper middle income            IBRD
# 2201          High income  Not classified
# 3493          High income  Not classified

# %%
# Tuple
df_2020.shape
# Out:
# (217, 9)

# %% [markdown]
# ## In-class Exercise
#
# Create a new column call "GDP Quartile" in the df_2020 dataframe and assign each country the quartile it belongs to by applying the assign_quartile() function.

# %%
df_2020["GDP Quartile"] = df_2020["GDP per Capita"].apply(assign_quartile)

print(df_2020.shape[0])
print(df_2020["GDP Quartile"].value_counts())
# Out:
# 217
# GDP Quartile
# 4th Quartile (>75%)      61
# 2nd Quartile (25-50%)    58
# 3rd Quartile (50-75%)    54
# 1st Quartile (<=25%)     44
# Name: count, dtype: int64

# %%
df_2020.sample(10)
# Out:
#       Year          Country  GDP per Capita  Life Expectancy  Population  \
# 3379  2020     South Africa     5753.066494        65.252000  58801927.0
# 3113  2020            Samoa     4042.722752        72.768000    214929.0
# 3797  2020     Turkmenistan     7330.366288        68.687000   6250438.0
# 2524  2020       Montenegro     7677.371321        75.931707    621306.0
# 1099  2020          Ecuador     5645.199290        72.153000  17588595.0
# 2866  2020            Palau    14349.316819              NaN     17972.0
# 2068  2020          Lao PDR     2593.355097        68.497000   7319399.0
# 1422  2020            Ghana     2176.576218        64.114000  32180401.0
# 1593  2020           Guyana     6863.074346        68.486000    797202.0
# 757   2020  Channel Islands    57339.526871        81.264000    171113.0
#
#      Country Code                      Region         Income Group  \
# 3379          ZAF         Sub-Saharan Africa   Upper middle income
# 3113          WSM         East Asia & Pacific  Lower middle income
# 3797          TKM       Europe & Central Asia  Upper middle income
# 2524          MNE       Europe & Central Asia  Upper middle income
# 1099          ECU  Latin America & Caribbean   Upper middle income
# 2866          PLW         East Asia & Pacific  Upper middle income
# 2068          LAO         East Asia & Pacific  Lower middle income
# 1422          GHA         Sub-Saharan Africa   Lower middle income
# 1593          GUY  Latin America & Caribbean           High income
# 757           CHI       Europe & Central Asia          High income
#
#         Lending Type           GDP Quartile
# 3379            IBRD  2nd Quartile (25-50%)
# 3113             IDA  2nd Quartile (25-50%)
# 3797            IBRD  3rd Quartile (50-75%)
# 2524            IBRD  3rd Quartile (50-75%)
# 1099            IBRD  2nd Quartile (25-50%)
# 2866            IBRD  3rd Quartile (50-75%)
# 2068             IDA  2nd Quartile (25-50%)
# 1422             IDA  2nd Quartile (25-50%)
# 1593             IDA  3rd Quartile (50-75%)
# 757   Not classified    4th Quartile (>75%)

# %%
df_4th = df_2020[df_2020["GDP Quartile"] == "4th Quartile (>75%)"]
df_4th.shape
# Out:
# (61, 10)

# %%
", ".join(list(df_4th["Country"]))
# Out:
# "Andorra, Aruba, Australia, Austria, Bahamas, The, Bahrain, Belgium, Bermuda, British Virgin Islands, Brunei Darussalam, Canada, Cayman Islands, Channel Islands, Cyprus, Czechia, Denmark, Eritrea, Estonia, Faroe Islands, Finland, France, Germany, Gibraltar, Greenland, Guam, Hong Kong SAR, China, Iceland, Ireland, Isle of Man, Israel, Italy, Japan, Korea, Dem. People's Rep., Korea, Rep., Kuwait, Liechtenstein, Luxembourg, Macao SAR, China, Malta, Monaco, Netherlands, New Caledonia, New Zealand, Norway, Portugal, Puerto Rico, Qatar, San Marino, Singapore, Sint Maarten (Dutch part), Slovenia, South Sudan, Spain, St. Martin (French part), Sweden, Switzerland, United Arab Emirates, United Kingdom, United States, Venezuela, RB, Virgin Islands (U.S.)"

# %%
quartile_groups = df_2020.groupby("GDP Quartile")["Country"].apply(list)


for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
for quartile, countries in quartile_groups.items():
  print(f"{quartile}:")
  for country in countries:
      print(f"  - {country}")
  print("\n")
# Out:
# 1st Quartile (<=25%):
#   - Afghanistan
#   - Angola
#   - Benin
#   - Burkina Faso
#   - Burundi
#   - Cambodia
#   - Cameroon
#   - Central African Republic
#   - Chad
#   - Comoros
#   - Congo, Dem. Rep.
#   - Ethiopia
#   - Gambia, The
#   - Guinea
#   - Guinea-Bissau
#   - Haiti
#   - Kiribati
#   - Kyrgyz Republic
#   - Lesotho
#   - Liberia
#   - Madagascar
#   - Malawi
#   - Mali
#   - Mauritania
#   - Mozambique
#   - Myanmar
#   - Nepal
#   - Niger
#   - Pakistan
#   - Rwanda
#   - Senegal
#   - Sierra Leone
#   - Somalia
#   - Sudan
#   - Syrian Arab Republic
#   - Tajikistan
#   - Tanzania
#   - Timor-Leste
#   - Togo
#   - Uganda
#   - Uzbekistan
#   - Yemen, Rep.
#   - Zambia
#   - Zimbabwe
#
#
# 2nd Quartile (25-50%):
#   - Albania
#   - Algeria
#   - Armenia
#   - Azerbaijan
#   - Bangladesh
#   - Belize
#   - Bhutan
#   - Bolivia
#   - Botswana
#   - Cabo Verde
#   - Colombia
#   - Congo, Rep.
#   - Cote d'Ivoire
#   - Djibouti
#   - Ecuador
#   - Egypt, Arab Rep.
#   - El Salvador
#   - Eswatini
#   - Fiji
#   - Georgia
#   - Ghana
#   - Guatemala
#   - Honduras
#   - India
#   - Indonesia
#   - Iran, Islamic Rep.
#   - Iraq
#   - Jamaica
#   - Jordan
#   - Kenya
#   - Kosovo
#   - Lao PDR
#   - Lebanon
#   - Marshall Islands
#   - Micronesia, Fed. Sts.
#   - Moldova
#   - Mongolia
#   - Morocco
#   - Namibia
#   - Nicaragua
#   - Nigeria
#   - North Macedonia
#   - Papua New Guinea
#   - Paraguay
#   - Philippines
#   - Samoa
#   - Sao Tome and Principe
#   - Solomon Islands
#   - South Africa
#   - Sri Lanka
#   - Suriname
#   - Tonga
#   - Tunisia
#   - Tuvalu
#   - Ukraine
#   - Vanuatu
#   - Viet Nam
#   - West Bank and Gaza
#
#
# 3rd Quartile (50-75%):
#   - American Samoa
#   - Antigua and Barbuda
#   - Argentina
#   - Barbados
#   - Belarus
#   - Bosnia and Herzegovina
#   - Brazil
#   - Bulgaria
#   - Chile
#   - China
#   - Costa Rica
#   - Croatia
#   - Cuba
#   - Curacao
#   - Dominica
#   - Dominican Republic
#   - Equatorial Guinea
#   - French Polynesia
#   - Gabon
#   - Greece
#   - Grenada
#   - Guyana
#   - Hungary
#   - Kazakhstan
#   - Latvia
#   - Libya
#   - Lithuania
#   - Malaysia
#   - Maldives
#   - Mauritius
#   - Mexico
#   - Montenegro
#   - Nauru
#   - Northern Mariana Islands
#   - Oman
#   - Palau
#   - Panama
#   - Peru
#   - Poland
#   - Romania
#   - Russian Federation
#   - Saudi Arabia
#   - Serbia
#   - Seychelles
#   - Slovak Republic
#   - St. Kitts and Nevis
#   - St. Lucia
#   - St. Vincent and the Grenadines
#   - Thailand
#   - Trinidad and Tobago
#   - Turkiye
#   - Turkmenistan
#   - Turks and Caicos Islands
#   - Uruguay
#
#
# 4th Quartile (>75%):
#   - Andorra
#   - Aruba
#   - Australia
#   - Austria
#   - Bahamas, The
#   - Bahrain
#   - Belgium
#   - Bermuda
#   - British Virgin Islands
#   - Brunei Darussalam
#   - Canada
#   - Cayman Islands
#   - Channel Islands
#   - Cyprus
#   - Czechia
#   - Denmark
#   - Eritrea
#   - Estonia
#   - Faroe Islands
#   - Finland
#   - France
#   - Germany
#   - Gibraltar
#   - Greenland
#   - Guam
#   - Hong Kong SAR, China
#   - Iceland
#   - Ireland
#   - Isle of Man
#   - Israel
#   - Italy
#   - Japan
#   - Korea, Dem. People's Rep.
#   - Korea, Rep.
#   - Kuwait
#   - Liechtenstein
#   - Luxembourg
#   - Macao SAR, China
#   - Malta
#   - Monaco
#   - Netherlands
#   - New Caledonia
#   - New Zealand
#   - Norway
#   - Portugal
#   - Puerto Rico
#   - Qatar
#   - San Marino
#   - Singapore
#   - Sint Maarten (Dutch part)
#   - Slovenia
#   - South Sudan
#   - Spain
#   - St. Martin (French part)
#   - Sweden
#   - Switzerland
#   - United Arab Emirates
#   - United Kingdom
#   - United States
#   - Venezuela, RB
#   - Virgin Islands (U.S.)

# %%
df_2020 = df_2020.dropna()
df_2020["GDP (Rounded)"] = df_2020["GDP per Capita"].apply(round)
df_2020.sample(5)
# Out:
#       Year      Country  GDP per Capita  Life Expectancy  Population  \
# 4082  2020  Yemen, Rep.      578.512010         64.65000  32284046.0
# 3436  2020    Sri Lanka     3852.389091         76.39300  21919000.0
# 1308  2020       France    39179.744260         82.17561  67571107.0
# 1137  2020  El Salvador     3961.726633         71.06100   6292731.0
# 1935  2020        Kenya     1936.250755         62.67500  51985780.0
#
#      Country Code                      Region         Income Group  \
# 4082          YEM  Middle East & North Africa           Low income
# 3436          LKA                  South Asia  Lower middle income
# 1308          FRA       Europe & Central Asia          High income
# 1137          SLV  Latin America & Caribbean   Upper middle income
# 1935          KEN         Sub-Saharan Africa   Lower middle income
#
#         Lending Type           GDP Quartile  GDP (Rounded)
# 4082             IDA   1st Quartile (<=25%)            579
# 3436             IDA  2nd Quartile (25-50%)           3852
# 1308  Not classified    4th Quartile (>75%)          39180
# 1137            IBRD  2nd Quartile (25-50%)           3962
# 1935           Blend  2nd Quartile (25-50%)           1936

# %%
def pop_million(pop):
    return pop / 1000000


df_2020["Population (Million)"] = df_2020["Population"].apply(pop_million)

df_2020.sample(5)
# Out:
#       Year          Country  GDP per Capita  Life Expectancy   Population  \
# 2961  2020      Philippines     3224.422811        72.119000  112190977.0
# 2049  2020  Kyrgyz Republic     1256.929226        71.800000    6579900.0
# 3835  2020           Tuvalu     4674.911403        64.382000      11069.0
# 2771  2020  North Macedonia     5965.450232        74.395122    2072531.0
# 1308  2020           France    39179.744260        82.175610   67571107.0
#
#      Country Code                 Region         Income Group    Lending Type  \
# 2961          PHL    East Asia & Pacific  Lower middle income            IBRD
# 2049          KGZ  Europe & Central Asia  Lower middle income             IDA
# 3835          TUV    East Asia & Pacific  Upper middle income             IDA
# 2771          MKD  Europe & Central Asia  Upper middle income            IBRD
# 1308          FRA  Europe & Central Asia          High income  Not classified
#
#                GDP Quartile  GDP (Rounded)  Population (Million)
# 2961  2nd Quartile (25-50%)           3224            112.190977
# 2049   1st Quartile (<=25%)           1257              6.579900
# 3835  2nd Quartile (25-50%)           4675              0.011069
# 2771  2nd Quartile (25-50%)           5965              2.072531
# 1308    4th Quartile (>75%)          39180             67.571107

# %%
df_2020["Population2 (Million)"] = df_2020["Population"].apply(lambda pop : pop / 1000000)
df_2020.sample(5)
# Out:
#       Year        Country  GDP per Capita  Life Expectancy  Population  \
# 909   2020  Cote d'Ivoire     2349.069882        59.032000  26811790.0
# 1498  2020        Grenada     8437.536782        74.924000    123663.0
# 1365  2020    Gambia, The      704.030463        62.612000   2573995.0
# 1992  2020    Korea, Rep.    31721.298914        83.426829  51836239.0
# 2942  2020           Peru     6063.626923        73.665000  33304756.0
#
#      Country Code                      Region         Income Group  \
# 909           CIV         Sub-Saharan Africa   Lower middle income
# 1498          GRD  Latin America & Caribbean   Upper middle income
# 1365          GMB         Sub-Saharan Africa            Low income
# 1992          KOR         East Asia & Pacific          High income
# 2942          PER  Latin America & Caribbean   Upper middle income
#
#         Lending Type           GDP Quartile  GDP (Rounded)  \
# 909              IDA  2nd Quartile (25-50%)           2349
# 1498           Blend  3rd Quartile (50-75%)           8438
# 1365             IDA   1st Quartile (<=25%)            704
# 1992  Not classified    4th Quartile (>75%)          31721
# 2942            IBRD  3rd Quartile (50-75%)           6064
#
#       Population (Million)  Population2 (Million)
# 909              26.811790              26.811790
# 1498              0.123663               0.123663
# 1365              2.573995               2.573995
# 1992             51.836239              51.836239
# 2942             33.304756              33.304756

# %% [markdown]
# ## Homework Question 1
#
# Save the summary statistics of all numerical columns and all categorical columns to only one Excel spreadsheet file with two worksheets, one for numerical and one for categorical columns.

# %%
df_numerical = df.describe().T

# %%
df_numerical.to_excel("numerical_summary.xlsx")

# %%
df.describe(include="object").T
# Out:
#              count unique                    top  freq
# Country       4123    217            Afghanistan    19
# Country Code  4123    217                    AFG    19
# Region        4123      7  Europe & Central Asia  1102
# Income Group  4123      5            High income  1558
# Lending Type  4123      4         Not classified  1387

# %%
df_categorical = df.describe(include="object").T

# %%
df_categorical.to_excel("categorical_summary.xlsx")

# %% [markdown]
# ## Homework Question 2
#
# Create a new column that is the GDP per Capita rounded to 2 decimal points by using the Python's build function "round"
# Hint: apply the round function/method and provide a parameter 2.

# %%
df2 = df.dropna()
df2["GDP (Rounded)"] = df2["GDP per Capita"].apply(lambda x: round(x, 2))
df2.sample(5)
# Out:
#       Year                Country  GDP per Capita  Life Expectancy  \
# 1531  2015              Guatemala     3994.629085        72.103000
# 1062  2021               Dominica     7668.158132        72.814000
# 647   2005               Cameroon     1129.357979        54.362000
# 3138  2007  Sao Tome and Principe      878.135470        64.724000
# 1289  2020                Finland    49169.719339        81.931707
#
#       Population Country Code                      Region  \
# 1531  15567419.0          GTM  Latin America & Caribbean
# 1062     72412.0          DMA  Latin America & Caribbean
# 647   17275171.0          CMR         Sub-Saharan Africa
# 3138    169845.0          STP         Sub-Saharan Africa
# 1289   5529543.0          FIN       Europe & Central Asia
#
#              Income Group    Lending Type  GDP (Rounded)
# 1531  Upper middle income            IBRD        3994.63
# 1062  Upper middle income           Blend        7668.16
# 647   Lower middle income           Blend        1129.36
# 3138  Lower middle income             IDA         878.14
# 1289          High income  Not classified       49169.72

# %% [markdown]
# ## Homework Question 3 (bonus, will cover next week)
#
# step 1 - create a column "Life Expectancy Quartile" similar to the GDP per Capita Quartile above.
# Step 2 - Create a column "health and wealth status" based on the following definition
# - rich and healthy (1st GDP per capita quartile and 1st life expentancy quartile)
# - poor and unhealthy ((4th GDP per capita quartile and 4th life expentancy quartile)
# - rich and unhealthy (1st GDP per capita quartile and 4th life expentancy quartile)
# - poor and healthy ((4th GDP per capita quartile and 1st life expentancy quartile)
# - Other

# %%
# Calculate quartiles
q1 = df['Life Expectancy'].quantile(0.25)  # 1st quartile (25th percentile)
q2 = df['Life Expectancy'].quantile(0.50)  # 2nd quartile (50th percentile or median)
q3 = df['Life Expectancy'].quantile(0.75)  # 3rd quartile (75th percentile)

# %%
q1
# Out:
# 65.351

# %%
q2
# Out:
# 72.765

# %%
q3
# Out:
# 77.529

# %%
df2["GDP Quartile"] = df2["GDP per Capita"].apply(assign_quartile)

print(df2.shape[0])
print(df2["GDP Quartile"].value_counts())
# Out:
# 3641
# GDP Quartile
# 1st Quartile (<=25%)     953
# 2nd Quartile (25-50%)    943
# 3rd Quartile (50-75%)    879
# 4th Quartile (>75%)      866
# Name: count, dtype: int64

# %%
def assign_quartile_life_expectations(gdp):
    if gdp <= q1:
        quartile = "1st Quartile (<=25%)"
    elif gdp > q1 and gdp <= q2:
        quartile = "2nd Quartile (25-50%)"
    elif gdp > q2 and gdp <= q3:
        quartile = "3rd Quartile (50-75%)"
    else:
        quartile = "4th Quartile (>75%)"
    return quartile

# %%
df2["Life Expectancy Quartile"] = df2["Life Expectancy"].apply(assign_quartile_life_expectations)

print(df2.shape[0])
print(df2["Life Expectancy Quartile"].value_counts())
# Out:
# 3641
# Life Expectancy Quartile
# 2nd Quartile (25-50%)    921
# 1st Quartile (<=25%)     918
# 4th Quartile (>75%)      904
# 3rd Quartile (50-75%)    898
# Name: count, dtype: int64

# %% [markdown]
# step 1 - create a column "Life Expectancy Quartile" similar to the GDP per Capita Quartile above.
# Step 2 - Create a column "health and wealth status" based on the following definition
# - rich and healthy (1st GDP per capita quartile and 1st life expentancy quartile)
# - poor and unhealthy ((4th GDP per capita quartile and 4th life expentancy quartile)
# - rich and unhealthy (1st GDP per capita quartile and 4th life expentancy quartile)
# - poor and healthy ((4th GDP per capita quartile and 1st life expentancy quartile)
# - Other

# %%
def assign_quartile_life_expectations(gdp_quartile, life_expectancy_quartile):
    if gdp_quartile == "1st Quartile (<=25%)" and life_expectancy_quartile == "1st Quartile (<=25%)":
        status = "rich and healthy"
    elif gdp_quartile == "4th Quartile (>75%)" and life_expectancy_quartile == "4th Quartile (>75%)":
        status = "poor and unhealthy"
    elif gdp_quartile == "1st Quartile (<=25%)" and life_expectancy_quartile == "4th Quartile (>75%)":
        status = "rich and unhealthy"
    elif gdp_quartile == "4th Quartile (>75%)" and life_expectancy_quartile == "1st Quartile (<=25%)":
        status = "poor and healthy"
    else:
      status = "Other"
    return status

# %%
df2["health and wealth status"] = df2.apply(lambda row: assign_quartile_life_expectations(row["GDP Quartile"], row["Life Expectancy Quartile"]), axis=1)

# %%
df2.sample(5)
# Out:
#       Year     Country  GDP per Capita  Life Expectancy  Population  \
# 3217  2010  Seychelles    10938.152764        73.197561     89770.0
# 2524  2020  Montenegro     7677.371321        75.931707    621306.0
# 3869  2016     Ukraine     2187.727539        71.476341  45004673.0
# 1015  2012     Denmark    58507.508052        80.051220   5591572.0
# 376   2019      Belize     6134.215233        73.931000    389095.0
#
#      Country Code                      Region         Income Group  \
# 3217          SYC         Sub-Saharan Africa           High income
# 2524          MNE       Europe & Central Asia  Upper middle income
# 3869          UKR       Europe & Central Asia  Lower middle income
# 1015          DNK       Europe & Central Asia          High income
# 376           BLZ  Latin America & Caribbean   Upper middle income
#
#         Lending Type  GDP (Rounded)           GDP Quartile  \
# 3217            IBRD       10938.15  3rd Quartile (50-75%)
# 2524            IBRD        7677.37  3rd Quartile (50-75%)
# 3869            IBRD        2187.73  2nd Quartile (25-50%)
# 1015  Not classified       58507.51    4th Quartile (>75%)
# 376             IBRD        6134.22  3rd Quartile (50-75%)
#
#      Life Expectancy Quartile health and wealth status
# 3217    3rd Quartile (50-75%)                    Other
# 2524    3rd Quartile (50-75%)                    Other
# 3869    2nd Quartile (25-50%)                    Other
# 1015      4th Quartile (>75%)       poor and unhealthy
# 376     3rd Quartile (50-75%)                    Other
